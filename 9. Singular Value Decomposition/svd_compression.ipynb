# %% [markdown]
# # 运用SVD进行图像压缩

# %%
# 导入相关包
import cv2
import numpy as np
from numpy.linalg import svd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 读取图片

# %%
# 读取图片
cimg = cv2.imread(r'.\images\image01.jpg')
print(cimg.shape)
plt.imshow(cv2.cvtColor(cimg,cv2.COLOR_BGR2RGB))
# Out:
# (800, 1200, 3)

# %%
# 灰度图片
img = cv2.cvtColor(cimg,cv2.COLOR_BGR2GRAY)
print(img.shape)
plt.imshow(img,cmap='gray')
# Out:
# (800, 1200)

# %% [markdown]
# ## 奇异值分解

# %%
U,s,VT = svd(img)
U.shape,s.shape,VT.shape
# Out:
# ((800, 800), (800,), (1200, 1200))

# %%
plt.plot(np.log(s))

# %% [markdown]
# ## 图像重建

# %%
num = 100
re_img = U[:,:num].dot(np.diag(s[:num])).dot(VT[:num,:])
re_img.shape
# Out:
# (800, 1200)

# %%
plt.imshow(re_img,cmap='gray')

# %%
## 重建误差
error = np.sqrt(np.sum((img-re_img)**2)) # F-norm
error2 = np.sqrt(sum(s[num:]**2))

# %%
error,error2
# Out:
# (7838.417817284977, 7838.417817284978)

# %%
800*1200
# Out:
# 960000

# %%
(800*100+100+100*1200)/(800*1200*8)
# Out:
# 1.6675
